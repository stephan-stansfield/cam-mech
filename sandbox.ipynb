# %%
range(360)
print(range(180))
len(range(180))
# Out:
# range(0, 180)
# 180

# %%
import numpy as np

length_straight = .123 + .123 + .124 + .125 + .125
radius_array = np.array([7.002, 7.014, 7.029, 7.045, 7.064])
length_circle = np.cumsum(radius_array * 2*np.pi / 360)

length_straight
length_circle

radius_check = 7.002 * 2*np.pi / 360
radius_check
# Out:
# 0.12220795422464295
